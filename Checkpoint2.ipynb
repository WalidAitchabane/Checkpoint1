# %%
import numpy as np
import pandas as pd

# %%
#df=pd.read_csv(r"C:\Users\dell\anaconda3\titanic-passengers.CSV", sep=';')
df=pd.read_csv("titanic-passengers.csv", sep=';')
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708   NaN        C
# 887      0    2669   7.2292   NaN        C
# 888      0  315084   8.6625   NaN        S
# 889      0  349215   7.8958   NaN        S
# 890      0  250655  26.0000   NaN        S

# %%
df.tail(1)
# Out:
#      PassengerId Survived  Pclass  \
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  250655  26.0   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df[['Age', 'Survived']]
# Out:
#       Age Survived
# 0    28.0       No
# 1    25.0       No
# 2    20.0       No
# 3    29.0       No
# 4    31.0       No
# ..    ...      ...
# 886  14.0      Yes
# 887  22.0       No
# 888  30.0       No
# 889   NaN       No
# 890  19.0      Yes
#
# [891 rows x 2 columns]

# %%
df[0:4]
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
#
#       Sex   Age  SibSp  Parch  Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0  248740  13.0000    NaN        S
# 1    male  25.0      0      0  348123   7.6500  F G73        S
# 2    male  20.0      0      0  350050   7.8542    NaN        S
# 3  female  29.0      0      4  349909  21.0750    NaN        S

# %%
df.iloc[2:5,2:5]
# Out:
#    Pclass                                         Name     Sex
# 2       3                       Jensen, Mr. Hans Peder    male
# 3       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female
# 4       1                       Davidson, Mr. Thornton    male

# %%
df.iloc[1]
# Out:
# PassengerId                         76
# Survived                            No
# Pclass                               3
# Name           Moen, Mr. Sigurd Hansen
# Sex                               male
# Age                               25.0
# SibSp                                0
# Parch                                0
# Ticket                          348123
# Fare                              7.65
# Cabin                            F G73
# Embarked                             S
# Name: 1, dtype: object

# %%
df1=df.set_index('Name')
df1.head()
# Out:
#                                              PassengerId Survived  Pclass  \
# Name
# Collander, Mr. Erik Gustaf                           343       No       2
# Moen, Mr. Sigurd Hansen                               76       No       3
# Jensen, Mr. Hans Peder                               641       No       3
# Palsson, Mrs. Nils (Alma Cornelia Berglund)          568       No       3
# Davidson, Mr. Thornton                               672       No       1
#
#                                                 Sex   Age  SibSp  Parch  \
# Name
# Collander, Mr. Erik Gustaf                     male  28.0      0      0
# Moen, Mr. Sigurd Hansen                        male  25.0      0      0
# Jensen, Mr. Hans Peder                         male  20.0      0      0
# Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# Davidson, Mr. Thornton                         male  31.0      1      0
#
#                                                  Ticket     Fare  Cabin  \
# Name
# Collander, Mr. Erik Gustaf                       248740  13.0000    NaN
# Moen, Mr. Sigurd Hansen                          348123   7.6500  F G73
# Jensen, Mr. Hans Peder                           350050   7.8542    NaN
# Palsson, Mrs. Nils (Alma Cornelia Berglund)      349909  21.0750    NaN
# Davidson, Mr. Thornton                       F.C. 12750  52.0000    B71
#
#                                             Embarked
# Name
# Collander, Mr. Erik Gustaf                         S
# Moen, Mr. Sigurd Hansen                            S
# Jensen, Mr. Hans Peder                             S
# Palsson, Mrs. Nils (Alma Cornelia Berglund)        S
# Davidson, Mr. Thornton                             S

# %%
df[df['Age']>22]
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 3            568       No       3
# 4            672       No       1
# 5            105       No       3
# ..           ...      ...     ...
# 881          699       No       1
# 882          775      Yes       2
# 883          809       No       2
# 885          150       No       2
# 888          535       No       3
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                     Collander, Mr. Erik Gustaf    male  28.0      0      0
# 1                        Moen, Mr. Sigurd Hansen    male  25.0      0      0
# 3    Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0      4
# 4                         Davidson, Mr. Thornton    male  31.0      1      0
# 5                 Gustafsson, Mr. Anders Vilhelm    male  37.0      2      0
# ..                                           ...     ...   ...    ...    ...
# 881                     Thayer, Mr. John Borland    male  49.0      1      1
# 882        Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1      3
# 883                            Meyer, Mr. August    male  39.0      0      0
# 885            Byles, Rev. Thomas Roussel Davids    male  42.0      0      0
# 888                          Cacic, Miss. Marija  female  30.0      0      0
#
#          Ticket      Fare  Cabin Embarked
# 0        248740   13.0000    NaN        S
# 1        348123    7.6500  F G73        S
# 3        349909   21.0750    NaN        S
# 4    F.C. 12750   52.0000    B71        S
# 5       3101276    7.9250    NaN        S
# ..          ...       ...    ...      ...
# 881       17421  110.8833    C68        C
# 882       29105   23.0000    NaN        S
# 883      248723   13.0000    NaN        S
# 885      244310   13.0000    NaN        S
# 888      315084    8.6625    NaN        S
#
# [483 rows x 12 columns]

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId Survived  Pclass                               Name   Sex  \
# 0            343       No       2         Collander, Mr. Erik Gustaf  male
# 1             76       No       3            Moen, Mr. Sigurd Hansen  male
# 2            641       No       3             Jensen, Mr. Hans Peder  male
# 4            672       No       1             Davidson, Mr. Thornton  male
# 5            105       No       3     Gustafsson, Mr. Anders Vilhelm  male
# ..           ...      ...     ...                                ...   ...
# 883          809       No       2                  Meyer, Mr. August  male
# 884          278       No       2        Parkes, Mr. Francis "Frank"  male
# 885          150       No       2  Byles, Rev. Thomas Roussel Davids  male
# 887           61       No       3              Sirayanian, Mr. Orsen  male
# 889          102       No       3   Petroff, Mr. Pastcho ("Pentcho")  male
#
#       Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    28.0      0      0      248740  13.0000    NaN        S
# 1    25.0      0      0      348123   7.6500  F G73        S
# 2    20.0      0      0      350050   7.8542    NaN        S
# 4    31.0      1      0  F.C. 12750  52.0000    B71        S
# 5    37.0      2      0     3101276   7.9250    NaN        S
# ..    ...    ...    ...         ...      ...    ...      ...
# 883  39.0      0      0      248723  13.0000    NaN        S
# 884   NaN      0      0      239853   0.0000    NaN        S
# 885  42.0      0      0      244310  13.0000    NaN        S
# 887  22.0      0      0        2669   7.2292    NaN        C
# 889   NaN      0      0      349215   7.8958    NaN        S
#
# [577 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#df = df.drop('Cabin', axis = 1)
#df
number_of_elements = len(df["Cabin"])
print("Number of element: ", number_of_elements)
print(df["Cabin"].value_counts())
df["Cabin"].fillna('G6', inplace=True)
df.tail()
# Out:
# Number of element:  891
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: Cabin, Length: 147, dtype: int64
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0        0      0      248740  13.0000     G6        S
# 1        0      0      348123   7.6500  F G73        S
# 2        0      0      350050   7.8542     G6        S
# 3        0      4      349909  21.0750     G6        S
# 4        1      0  F.C. 12750  52.0000    B71        S
# ..     ...    ...         ...      ...    ...      ...
# 886      1      0      237736  30.0708     G6        C
# 887      0      0        2669   7.2292     G6        C
# 888      0      0      315084   8.6625     G6        S
# 889      0      0      349215   7.8958     G6        S
# 890      0      0      250655  26.0000     G6        S
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
df["Embarked"].fillna('S', inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Survived']=encoder.fit_transform(df['Survived'])
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000     G6        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542     G6        S
# 3  female  29.0      0      4      349909  21.0750     G6        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex']=encoder.fit_transform(df['Sex'])
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    1  28.0      0      0      248740  13.0000     G6        S
# 1    1  25.0      0      0      348123   7.6500  F G73        S
# 2    1  20.0      0      0      350050   7.8542     G6        S
# 3    0  29.0      0      4      349909  21.0750     G6        S
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df['Embarked'].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked']=encoder.fit_transform(df['Embarked'])
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin  Embarked
# 0    1  28.0      0      0      248740  13.0000     G6         2
# 1    1  25.0      0      0      348123   7.6500  F G73         2
# 2    1  20.0      0      0      350050   7.8542     G6         2
# 3    0  29.0      0      4      349909  21.0750     G6         2
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71         2

# %%
import matplotlib.pyplot as plt
plt.title("Histogram of diffrent ages")
plt.xlabel("Age")
df["Age"].plot.hist()
# Out:
# <Axes: title={'center': 'Histogram of diffrent ages'}, xlabel='Age', ylabel='Frequency'>

# %%
import seaborn as sns
sns.distplot(df["Age"], bins=10, hist=True, kde=True, color="red")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_6164\3212144581.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], bins=10, hist=True, kde=True, color="red")
# <Axes: xlabel='Age', ylabel='Density'>

# %%
plt.xlabel("Sex")
plt.ylabel("Sex value count")
plt.title("Bar plot of sex")
vc=df["Sex"].value_counts()
vc.plot.bar(rot=45)
# Out:
# <Axes: title={'center': 'Bar plot of sex'}, xlabel='Sex', ylabel='Sex value count'>

# %%
sns.countplot(x="Sex", data=df)
plt.xticks(rotation=-45)
# Out:
# (array([0, 1]), [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
df["Age"].plot.box()
# Out:
# <Axes: >

# %%
sns.boxplot(df["Age"], width=0.5)
# Out:
# <Axes: >

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={ 'shrink' : .9 }, ax=ax, annot = True, annot_kws = { 'fontsize' : 12 })

# %%
plot_correlation_map( df )
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_13256\3974750663.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()

# %%
colonne=['Age', 'Sex']
df4= df[colonne]
plot_correlation_map(df4)

# %%
colonne=['Age', 'Pclass']
df5= df[colonne]
plot_correlation_map(df5)
